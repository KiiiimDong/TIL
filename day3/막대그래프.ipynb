# %% [markdown]
# ## 막대그래프

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

단어 = ['좋아','싫어','부정','긍정']
횟수 = [10,100,5,20]
plt.bar(단어,횟수,color=['r','g','b','c'],alpha=0.5)
plt.plot(횟수,'b--')
plt.ylim(1,110)
# Out:
# (1.0, 110.0)

# %%
단어 = ['좋아','싫어','부정','긍정']
횟수 = [10,100,5,20]
plt.bar(단어,횟수,color=['r','g','b','c'],alpha=0.5,width=0.5)
plt.plot(횟수,'b--')
plt.ylim(1,110)
# Out:
# (1.0, 110.0)

# %%
단어 = ['좋아','싫어','부정','긍정']
횟수 = [10,100,5,20]
plt.bar(단어,횟수)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import numpy as np
단어 = ['좋아','싫어','부정','긍정']
횟수 = [10,100,5,20]
d=np.arange(4)
plt.barh(d,횟수)
plt.yticks(d,단어)
# Out:
# ([<matplotlib.axis.YTick at 0x213e75f47f0>,
#   <matplotlib.axis.YTick at 0x213e75eefa0>,
#   <matplotlib.axis.YTick at 0x213e75ee3a0>,
#   <matplotlib.axis.YTick at 0x213e7624880>],
#  [Text(0, 0, '좋아'), Text(0, 1, '싫어'), Text(0, 2, '부정'), Text(0, 3, '긍정')])

# %%
단어 = ['좋아','싫어','부정','긍정']
횟수 = [10,100,5,20]
plt.barh(단어,횟수)
#plt.text()
# Out:
# <BarContainer object of 4 artists>

# %%
b=plt.barh(단어,횟수)
for i,d in enumerate(b):
    plt.text(횟수[i]+5,i,횟수[i],ha='center')

# %%
b2=plt.bar(단어,횟수)
for i,d in enumerate(b2):
    plt.text(i,d.get_height() + 0.5,횟수[i],ha='center', color='blue')

# %%
d1=np.random.rand(100,2)#데이터 차원제시가능.
d2=np.random.rand(100,2)
#plt.scatter(x축,y축,)
plt.scatter(d1[:,0],d1[:,1],c="r",marker='*')
plt.scatter(d2[:,0],d2[:,1],c="b",marker='o')

# %% [markdown]
# ## 막대그래프 심화

# %%
단어 = ['좋아','싫어','부정','긍정']
x=np.arange(0,8,2)
A_횟수 = [10,100,5,20]
B_횟수 = [100,20,10,30]
C_횟수 = [90,20,50,100]
plt.bar(x+0.00,A_횟수,width=0.5)
plt.bar(x+0.50,B_횟수,width=0.5)
plt.bar(x+1.00,C_횟수,width=0.5)
plt.xticks(x+0.5,단어)
# Out:
# ([<matplotlib.axis.XTick at 0x213e71e07c0>,
#   <matplotlib.axis.XTick at 0x213e71e0a00>,
#   <matplotlib.axis.XTick at 0x213e71e01f0>,
#   <matplotlib.axis.XTick at 0x213e7291ee0>],
#  [Text(0.5, 0, '좋아'),
#   Text(2.5, 0, '싫어'),
#   Text(4.5, 0, '부정'),
#   Text(6.5, 0, '긍정')])

# %%
x=['득표율']
y1=[10]
y2=[20]
y3=[30]
i_d=[40]
plt.bar(x,i_d)
plt.bar(x,y3,bottom=i_d)
plt.bar(x,y2,bottom=y3[0]+i_d[0])
plt.bar(x,y1,bottom=y2[0]+y3[0]+i_d[0])
# Out:
# <BarContainer object of 1 artists>

# %%
단어 = ['좋아_data','싫어_data','부정_data','긍정_data']
A_횟수 = np.array([10,100,5,20])
B_횟수 = np.array([100,20,10,30])
C_횟수 = np.array([90,20,50,100])
plt.bar(단어,A_횟수,label='A')
plt.bar(단어,B_횟수,bottom=A_횟수,label='B')
plt.bar(단어,C_횟수,bottom=A_횟수+B_횟수,label='C')
plt.xticks(rotation=45)
plt.legend()

# %%
n=10000
X=np.random.normal(size=n)
plt.hist(X,bins=100)
plt.show()
