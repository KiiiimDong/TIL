# %%
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# %%
all_data = DoublespaceLineCorpus('data1.txt', iter_sent=True)
len(all_data) # 문장으로 받아서 Ex1 에서 문서로 받은거랑 길이가 다르다.
# Out:
# 223357

# %%
n = 0
for i in all_data:
    print(i)
    n+=1
    if n==4:
        break
# Out:
# 19
# 1990
# 52 1 22
# 오패산터널 총격전 용의자 검거 서울 연합뉴스 경찰 관계자들이 19일 오후 서울 강북구 오패산 터널 인근에서 사제 총기를 발사해 경찰을 살해한 용의자 성모씨를 검거하고 있다 성씨는 검거 당시 서바이벌 게임에서 쓰는 방탄조끼에 헬멧까지 착용한 상태였다 독자제공 영상 캡처 연합뉴스

# %%
m = WordExtractor() #글자추출 클래스
m.train(all_data)
# Out:
# training was done. used memory 0.646 Gbse memory 0.834 Gb

# %%
m.extract()
# Out:
# all cohesion probabilities was computed. # words = 223348
# all branching entropies was computed # words = 360721
# all accessor variety was computed # words = 360721
# {'릿': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=1.9071809787465375, right_branching_entropy=3.013295599848297, left_accessor_variety=9, right_accessor_variety=25, leftside_frequency=15, rightside_frequency=151),
#  '쉴': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=2.260046572101049, right_branching_entropy=1.4991145901180793, left_accessor_variety=13, right_accessor_variety=6, leftside_frequency=9, rightside_frequency=0),
#  '잊': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=2.7167860064601195, right_branching_entropy=1.545465661337347, left_accessor_variety=26, right_accessor_variety=7, leftside_frequency=234, rightside_frequency=0),
# ...

# %%
t1 = '영화가 너무 웃겨'
t2 = '영화가 너무 웃겨 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'
t3 = '영화가 너무 웃겨 ㅋㅋ'
t4 = '영화가 너무 웃겨 ㅋㅋㅋ'

# %%
from soynlp.normalizer import *

# %%
emoticon_normalize(t1)
# Out:
# '영화가 너무 웃겨'

# %%
emoticon_normalize(t2,num_repeats=3)
# Out:
# '영화가 너무 웃겨 ㅋㅋㅋ'

# %%
emoticon_normalize(t3,num_repeats=2)
# Out:
# '영화가 너무 웃겨 ㅋㅋ'

# %%
emoticon_normalize(t2,num_repeats=1)
# Out:
# '영화가 너무 웃겨 ㅋ'

# %%
t_e = '후후후후후후훗'
emoticon_normalize(t_e)
# Out:
# '후후훗'
