# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.wadiz.kr/web/wreward/main'
params = {
    'u': '%2Fweb%2Fwreward%2Fmain%3Fkeyword%3D%26endYn%3DALL%26order%3Drecommend',
'r': 'https%3A%2F%2Fwww.google.com%2F',
'a': '0000'}
resp = requests.get(url,params=params)
resp.text
# Out:
# '\n\n\n\n<!-- froala_editor_version 3.2.7 -->\n\n\n\n<!doctype html>\n<html lang="ko">\n<head>\n<!-- froala_editor_version 3.2.7 -->\n<style>.async-hide { opacity: 0 !important} </style>\n<script>(function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;\nh.end=i=function(){s.className=s.className.replace(RegExp(\' ?\'+y),\'\')};\n(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;\n})(window,document.documentElement,\'async-hide\',\'dataLayer\',4000,\n{\'GTM-NDMQ9N4\':true});</script>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no,user-scalable=no,viewport-fit=cover">\n<meta name="description" content="테크, 패션, 푸드, 뷰티, 홈리빙까지. 와디즈 펀딩으로 매일 새로운 일상을 발견하고, 와디즈 스토어에서 새로운 쇼핑을 만나보세요.">\n<meta property="fb:app_id" content="190622721088710">\n<meta property="og:type" content="website">\n<meta property="og:locale" content="ko_KR">\n<meta propert
# ...

# %%
resp.request.headers
# Out:
# {'User-Agent': 'python-requests/2.26.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'}

# %%
resp = requests.get(url,params=params, headers=headers)
resp.text
# Out:
# '\n\n\n\n<!-- froala_editor_version 3.2.7 -->\n\n\n\n<!doctype html>\n<html lang="ko">\n<head>\n<!-- froala_editor_version 3.2.7 -->\n<style>.async-hide { opacity: 0 !important} </style>\n<script>(function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;\nh.end=i=function(){s.className=s.className.replace(RegExp(\' ?\'+y),\'\')};\n(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;\n})(window,document.documentElement,\'async-hide\',\'dataLayer\',4000,\n{\'GTM-NDMQ9N4\':true});</script>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no,user-scalable=no,viewport-fit=cover">\n<meta name="description" content="테크, 패션, 푸드, 뷰티, 홈리빙까지. 와디즈 펀딩으로 매일 새로운 일상을 발견하고, 와디즈 스토어에서 새로운 쇼핑을 만나보세요.">\n<meta property="fb:app_id" content="190622721088710">\n<meta property="og:type" content="website">\n<meta property="og:locale" content="ko_KR">\n<meta propert
# ...

# %%
soup = BeautifulSoup(resp.text)

# %%
soup
# Out:
# <!-- froala_editor_version 3.2.7 --><!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- froala_editor_version 3.2.7 -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'GTM-NDMQ9N4':true});</script>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width,initial-scale=1,shrink-to-fit=no,user-scalable=no,viewport-fit=cover" name="viewport"/>
# <meta content="테크, 패션, 푸드, 뷰티, 홈리빙까지. 와디즈 펀딩으로 매일 새로운 일상을 발견하고, 와디즈 스토어에서 새로운 쇼핑을 만나보세요." name="description"/>
# <meta content="190622721088710" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# ...

# %%
data = soup.select('body.show-gnb')
data
# Out:
# []

# %%
url = 'https://static.wadiz.kr/static/floating-buttons/main.578aed1a.js'

# %%
resp = requests.get(url,params=params, headers=headers)

# %%
soup = BeautifulSoup(resp.text)

# %%
soup
# Out:
# <html><body><p>!function(e,t){if("object"===typeof exports&amp;&amp;"object"===typeof module)module.exports=t(require("Sentry"),require("jQuery"));else if("function"===typeof define&amp;&amp;define.amd)define(["Sentry","jQuery"],t);else{var n="object"===typeof exports?t(require("Sentry"),require("jQuery")):t(e.Sentry,e.jQuery);for(var r in n)("object"===typeof exports?exports:e)[r]=n[r]}}(window,(function(e,t){return function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}return n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){"undefined"!==typeof Symbol&amp;&amp;Symbol.toStringTag&amp;&amp;Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&amp;t&amp;&amp;(e=n(e)),8&amp;t)return e;if(4&amp;t&amp;&amp;"object"===typeof e&amp;&amp;e&amp;&amp;e.__esM
# ...
