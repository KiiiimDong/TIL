# %% [markdown]
# ## 정해진 금융 데이터를 수집하고 .csv 파일로 저장하여 판다스를 이용한 테이블을 완성.
#     - 동적 크롤링을 이용하여 data를 수집해주세요.
#     - 정해진 data를 스크래핑 하고 .csv 파일로 저장하시오
#     - 판다스를 이용하여 data table을 구성하시오.

# %%
import pandas as pd
from pandas import DataFrame
df_data=pd.read_csv('data.csv',encoding="utf-8-sig")
df=DataFrame(df_data)
df
# Out:
#       제목                                      내용
# 0    통화명                         통화명심볼현재가전일대비등락율
# 1     심볼    영국 파운드/달러GBPUSD1.3067  0.0021- 0.16%
# 2    현재가        유로/달러EURUSD1.0910  0.0010- 0.09%
# 3   전일대비     호주 달러/달러AUDUSD0.7474  0.0061- 0.80%
# 4    등락율       달러/홍콩 달러USDHKD7.8375 0.0009+0.01%
# 5    통화명      달러/일본 엔USDJPY123.9100 0.1800+0.14%
# 6     심볼      달러/캐나다 달러USDCAD1.2585 0.0082+0.65%
# 7    현재가   달러/아랍에미리트 디르함USDAED3.6731 0.00000.00%
# 8   전일대비     달러/네델란드 안틸레USDANG1.8020 0.00010.00%
# 9    등락율  달러/아르헨티나 페소USDARS111.9883 0.1494+0.13%
# 10   통화명     달러/불가리아 레브USDBGN1.7931 0.0037+0.20%
# 11    심볼      달러/브라질 레알USDBRL4.7620 0.0680+1.44%
# 12   현재가      달러/스위스 프랑USDCHF0.9331 0.0005+0.05%
# 13  전일대비    달러/칠레 페소USDCLP809.9500 16.1200+2.03%
# 14   등락율       달러/중국 위안USDCNY6.3593 0.0011+0.01%

# %%
b.switch_to.window(b.window_handles[1])#탭전환
b.switch_to.frame("html문서의이름")
